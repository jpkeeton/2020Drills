# %% [markdown]
# Building Permits from Socrata

# %%
import pandas as pd

building_permits = pd.read_csv('C:/Users/jpkee/Documents/My Tableau Repository/Datasources/Building_Permits.csv')


# import pandas as pd

# taxi_data = pd.read_csv('C:/Users/jpkee/Documents/My Tableau Repository/Datasources/')

# %%
building_permits.head(3)
# Out:
#     PermitNum           PermitClass PermitClassMapped PermitTypeMapped  \
# 0  6617360-CN  Single Family/Duplex       Residential         Building
# 1  6616847-CN         Institutional   Non-Residential         Building
# 2  6567607-CN  Single Family/Duplex       Residential         Building
#
#         PermitTypeDesc                                        Description  \
# 0  Addition/Alteration                                   Basement Remodel
# 1                  New  Shoring and Excavation for Construction of off...
# 2  Addition/Alteration  Construct alterations, remove a dwelling unit ...
#
#    HousingUnits  HousingUnitsRemoved  HousingUnitsAdded  EstProjectCost  ...  \
# 0           NaN                  0.0                0.0         65000.0  ...
# 1           NaN                  0.0                0.0       1800000.0  ...
# 2           NaN                  1.0                1.0        125000.0  ...
#
#   StatusCurrent        OriginalAddress1 OriginalCity OriginalState  \
# ...
