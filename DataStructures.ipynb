# %% [markdown]
# # Data Structures
#
# 1. https://www.datacamp.com/community/tutorials/data-structures-python
# 2. https://docs.python.org/3/tutorial/datastructures.html
# 3. https://python.swaroopch.com/data_structures.html
# 4. https://thomas-cokelaer.info/tutorials/python/data_structures.html

# %%
#pulling in image bit
from IPython.display import Image

# %%
Image('C:/Users/jpkee/Desktop/PythonProjects/Pictures/DataCampDataStructures.png')
#Here's a breakdown

# %%
Image('C:/Users/jpkee/Desktop/PythonProjects/Pictures/Python_3._The_standard_type_hierarchy.png')
# Per https://en.wikipedia.org/wiki/Data_type#/media/File:Python_3._The_standard_type_hierarchy.png

# %%
# range slicing
new_string = "Jeremy Keeton"

# %%
string_range = new_string[3:]
string_range
# Out:
# 'emy Keeton'

# %%
string_range2 = new_string[4:-3]
string_range2
# Out:
# 'my Kee'

# %%
# slicing
# grabbing bits of 'new_string'
string_slice =new_string[0] + new_string[5]

# %%
string_slice
# Out:
# 'Jy'

# %%
# get a string length
len(string_range2)
# Out:
# 6

# %%
# built-in string helper functions
# like capitalize, upper, title, etc
test_string = "2345a"
len(test_string)
# Out:
# 5

# %%
str.capitalize(test_string)
# Out:
# '2345a'

# %%
str.upper
# Out:
# <method 'upper' of 'str' objects>

# %%
str.upper(test_string)
# Out:
# '2345A'

# %%
str.lower(test_string)
# Out:
# '2345a'

# %%
# is a string has ONLY (numbers) digits?, so if your string variable had only numbers it would return true
str.isdigit(test_string)
# Out:
# False

# %%
thisList = ["apple", "bananas", "pear"]

# %%
print(thisList)
# Out:
# ['apple', 'bananas', 'pear']

# %%
print(thisList[0])
# Out:
# apple

# %%
thisSet = {"apple", "bananas", "pear"}

# %%
print(thisSet)
# Out:
# {'bananas', 'apple', 'pear'}
