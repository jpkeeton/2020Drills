# %%
# Text Analysis Studies
# https://www.geeksforgeeks.org/python-count-occurrences-of-each-word-in-given-text-file-using-dictionary/

# %%
# Open the file in read mode 
text = open("C:/Users/jpkee/Downloads/RNC_Transcript.txt", "r") 

# Create an empty dictionary 
d = dict() 

# Loop through each line of the file 
for line in text: 
	# Remove the leading spaces and newline character 
	line = line.strip() 

	# Convert the characters in line to 
	# lowercase to avoid case mismatch 
	line = line.lower() 

	# Split the line into words 
	words = line.split(" ") 

	# Iterate over each word in line 
	for word in words: 
		# Check if the word is already in dictionary 
		if word in d: 
			# Increment count of word by 1 
			d[word] = d[word] + 1
		else: 
			# Add the word to dictionary with count 1 
			d[word] = 1

# Print the contents of dictionary 
for key in list(d.keys()): 
	print(key, ":", d[key])
# Out:
# speaker : 17
# 1 : 1
# (00:00:00): : 1
# thing, : 1
# it : 87
# was : 126
# never : 30
# intended : 2
# to : 570
# be, : 1
# but : 84
# the : 994
# spirit : 9
# of : 533
# heroism : 10
# stands : 3
# in : 381
# breach. : 1
# lives : 19
# heart. : 2
# breathes : 1
# soul : 1
# and : 691
# is : 172
# woven : 3
# into : 24
# courageous : 2
# fabric : 3
# americans, : 14
# like : 35
# you. : 17
# preserves : 1
# liberty. : 3
# strengthens : 1
# families. : 5
# empowers : 1
# extraordinary. : 1
# inspires : 1
# us : 49
# act : 3
# when : 72
# others : 4
# are : 83
# need, : 1
# do : 27
# right : 29
# thing. : 3
# join : 6
# tonight. : 5
# dream : 12
# heroic : 3
# dreams. : 2
# celebrate : 3
# america, : 13
# land : 17
# free, : 2
# home : 9
# brave. : 2
#  : 152
# 2 : 1
# (00:00:52): : 1
# from : 55
# washington : 12
# dc, : 1
# welcome : 5
# 2020 : 2
# republican : 14
# national : 22
# convention. : 4
# tonight, : 9
# celebrating : 2
# heroes. : 7
# 3 : 3
# (00:01:19): : 1
# lord, : 2
# ...

# %%
#Trump's RNC Speech
   
    
    # Open the file in read mode 
trump_text = open("C:/Users/jpkee/Documents/My Tableau Repository/Datasources/TrumpRNC_NominationAcceptanceSpeech.txt", "r") 

# Create an empty dictionary 
d = dict() 

# Loop through each line of the file 
for line in trump_text : 
	# Remove the leading spaces and newline character 
	line = line.strip() 

	# Convert the characters in line to 
	# lowercase to avoid case mismatch 
	line = line.lower() 

	# Split the line into words 
	words = line.split(" ") 

	# Iterate over each word in line 
	for word in words: 
		# Check if the word is already in dictionary 
		if word in d: 
			# Increment count of word by 1 
			d[word] = d[word] + 1
		else: 
			# Add the word to dictionary with count 1 
			d[word] = 1

# Print the contents of dictionary 
for key in list(d.keys()): 
	print(key, ":", d[key])
# Out:
# friends, : 1
# delegates : 1
# and : 185
# fellow : 1
# americans: : 1
# i : 77
# humbly : 1
# gratefully : 1
# accept : 1
# your : 12
# nomination : 1
# for : 50
# the : 226
# presidency : 3
# of : 143
# united : 5
# states. : 1
#  : 136
# who : 28
# would : 7
# have : 69
# believed : 2
# that : 62
# when : 12
# we : 78
# started : 1
# this : 38
# journey : 1
# on : 33
# june : 1
# 16, : 1
# last : 6
# year, : 4
# â€” : 15
# say : 5
# because : 10
# are : 51
# a : 69
# team : 1
# received : 5
# almost : 5
# 14 : 2
# million : 4
# votes, : 1
# most : 8
# in : 91
# history : 3
# republican : 2
# party? : 1
# party : 3
# get : 4
# 60 : 2
# percent : 6
# more : 13
# votes : 2
# than : 14
# it : 32
# eight : 2
# years : 8
# ago. : 3
# it? : 2
# democrats : 3
# other : 12
# hand, : 4
# 20 : 2
# fewer : 1
# they : 26
# got : 1
# four : 4
# ago, : 3
# not : 26
# so : 21
# good. : 3
# together, : 1
# will : 98
# lead : 3
# our : 104
# back : 6
# to : 146
# white : 3
# house, : 2
# ...

# %%
# Open the file in read mode 
text = open("C:/Users/jpkee/Documents/My Tableau Repository/Datasources/TrumpJRDNCSpeech.txt", "r") 

# Create an empty dictionary 
d = dict() 

# Loop through each line of the file 
for line in text: 
	# Remove the leading spaces and newline character 
	line = line.strip() 

	# Convert the characters in line to 
	# lowercase to avoid case mismatch 
	line = line.lower() 

	# Split the line into words 
	words = line.split(" ") 

	# Iterate over each word in line 
	for word in words: 
		# Check if the word is already in dictionary 
		if word in d: 
			# Increment count of word by 1 
			d[word] = d[word] + 1
		else: 
			# Add the word to dictionary with count 1 
			d[word] = 1

# Print the contents of dictionary 
for key in list(d.keys()): 
	print(key, ":", d[key])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-0147ecd62fc5> in <module>
#       6
#       7 # Loop through each line of the file
# ----> 8 for line in text:
#       9         # Remove the leading spaces and newline character
#      10         line = line.strip()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 3896: character maps to <undefined>
