# %%
import pandas as pd 
# Read data from file 'filename.csv' 
nbaStats = pd.read_csv("NBA 2018-19 Season.csv") 
# Preview the first 5 lines of the loaded data 
nbaStats.head(1000)
# or we can get a sample of rows w this command
nbaStats.sample(5)
# Out:
#     Conference   Division                    Team                   Player  \
# 394    Western  Northwest  Minnesota Timberwolves             Derrick Rose
# 63     Eastern   Atlantic      Philadelphia 76ers        Demetrius Jackson
# 478    Western    Pacific      Los Angeles Lakers              Alex Caruso
# 29     Eastern   Atlantic         Toronto Raptors               Jeremy Lin
# 230    Eastern  Southeast           Orlando Magic  Michael Carter-Williams
#
#      Age  Games  Games Started  Minutes Played  Field Goals  \
# 394   30     51             13            1392          363
# 63    24      6              0              39            8
# 478   24     25              4             531           77
# 29    30     23              3             433           58
# 230   27     12              0             227           21
#
#      Field Goal Attempts  ...  Free Throw Percentage  Offensive Rebounds  \
# 394                  753  ...                  0.856                  33
# ...

# %%
# now let's get the shape
nbaStats.shape
# Out:
# (622, 30)

# %%
# grab a couple columns
# per https://data36.com/pandas-tutorial-1-basics-reading-data-files-dataframes-data-selection/
# the outer bracket frames tell pandas that you want to select columns, 
# and the inner brackets are for the list of the column names.
nbaStats[['Division', 'Team']]
# Out:
#       Division              Team
# 0     Atlantic    Boston Celtics
# 1     Atlantic    Boston Celtics
# 2     Atlantic    Boston Celtics
# 3     Atlantic    Boston Celtics
# 4     Atlantic    Boston Celtics
# ..         ...               ...
# 617  Southwest  Dallas Mavericks
# 618  Southwest  Dallas Mavericks
# 619  Southwest  Dallas Mavericks
# 620  Southwest  Dallas Mavericks
# 621  Southwest  Dallas Mavericks
#
# [622 rows x 2 columns]

# %%
# https://www.marsja.se/pandas-sample-randomly-select-rows/
# now let's get a sample
# w/o a parameter we'll just get 1 row
nbaStats.sample()
# but let's get a sample of 10
nbaStats.sample(10)
# Out:
#     Conference   Division                    Team             Player  Age  \
# 504    Western    Pacific            Phoenix Suns      Tyler Johnson   26
# 495    Western    Pacific            Phoenix Suns     Jamal Crawford   38
# 297    Eastern  Southeast           Atlanta Hawks       John Collins   21
# 69     Eastern   Atlantic           Brooklyn Nets    DeMarre Carroll   32
# 327    Western  Northwest          Denver Nuggets      Isaiah Thomas   29
# 66     Eastern   Atlantic           Brooklyn Nets         Joe Harris   27
# 408    Western  Northwest  Minnesota Timberwolves        Mitch Creek   26
# 50     Eastern   Atlantic      Philadelphia 76ers       Jonah Bolden   23
# 538    Western  Southwest       San Antonio Spurs  LaMarcus Aldridge   33
# 310    Eastern  Southeast           Atlanta Hawks      Miles Plumlee   30
#
#      Games  Games Started  Minutes Played  Field Goals  Field Goal Attempts  \
# 504     13             12             406           46                  125
# ...

# %%
#how to select an average from a column?
