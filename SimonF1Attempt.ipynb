# %% [markdown]
# I'm going to try to get Simon's DB connection tutorials working

# %%
import pandas as pd
from sqlalchemy import create_engine
from sql_query import sql_select
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-c8f55f991f96> in <module>
#       1 import pandas as pd
#       2 from sqlalchemy import create_engine
# ----> 3 from sql_query import sql_select
#
# ImportError: cannot import name 'sql_select' from 'sql_query' (C:\Users\jpkee\anaconda3\lib\site-packages\sql_query\__init__.py)

# %%
engine = create_engine('sqlite:///C:/Users/jpkee/Documents/My Tableau Repository/Datasources/F1_data-master/F1_data-master/Formula1.db')

# C:\Users\jpkee\Documents\My Tableau Repository\Datasources\F1_data-master\F1_data-master

# %%
qry = sql.select(
                sl=['driverID, 'forename', 'surname'],
                fr='drivers'
                    )
# Out:
#   File "<ipython-input-14-a96bf41a7865>", line 2
#     sl=['driverID, 'forename', 'surname'],
#                            ^
# SyntaxError: invalid syntax

# %%
type(qry)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d8a0a508e47f> in <module>
# ----> 1 type(qry)
#
# NameError: name 'qry' is not defined
