# %% [markdown]
# **Working thru Simon's SQL tutorials**
# * https://www.youtube.com/watch?v=IrCowiKyyBA

# %%
import pandas as pd
from sqlalchemy import create_engine
from sql_query import sql_select
engine = create_engine('sqlite:///C:/Users/jpkee/Documents/My Tableau Repository/Datasources/F1_data-master/F1_data-master/Formula1.db')

# %%
# initialize a sql_select object

# sl  = SELECT
# fr = FROM 
# - parameter names can be omitted
qry = sql_select(
                sl=['driverId', 'forename', 'surname'],
                fr='drivers'
                    )

# %%
type(qry)
# Out:
# sql_query.sql_query.sql_select

# %%
# View the given attributes, grabbing the headers 
print(qry.sl)
# Out:
# ['driverId', 'forename', 'surname']

# %%
# view the table
print(qry.fr)
# Out:
# drivers

# %%
# use the select method to ADD a field to our query
qry.select('nationality')

# %%
# Check that we are now getting back 'nationality' as well
print(qry.sl)
# Out:
# ['forename', 'surname', 'nationality', 'driverId']

# %%
# change the fields, in this cas remove the previously provided fields
qry.select(['driverId', 'forename', 'surname'], clear = True)

# %%
# verify that we did indeed remove nationality
print(qry.sl)
# Out:
# ['driverId', 'forename', 'surname']

# %%
# get your sql query as txt
print(qry)
# Out:
# SELECT driverId, forename, surname FROM drivers

# %%
## this is fun get the top rows with head function
data = pd.read_sql(str(qry), con=engine)

# %%
data.shape
# Out:
# (847, 3)

# %%
data.tail()
# Out:
#      driverId   forename   surname
# 842       844    Charles   Leclerc
# 843       845     Sergey  Sirotkin
# 844       846      Lando    Norris
# 845       847     George   Russell
# 846       848  Alexander     Albon

# %% [markdown]
# **Video #2**
# * https://www.youtube.com/watch?v=l5_tcFaG0nM

# %%
# create a new select
s_qry = sql_select(['driverID', 'forename', 'surname'], 'drivers')
# more on sql_select here: https://programmer.spip.net/sql_select,655

# %%
# so basically here we are grabbing the columns and telling the query that 'drivers' is the table
 ## SELECT driverId, forename, surname FROM drivers, print it to confirm
print(s_qry)
# Out:
# SELECT driverID, forename, surname FROM drivers

# %%
# Basic Where statements
# use the .where method
# attribute is the field, cond is the value to search for in that field`
s_qry.where(attr="nationality", cond="Dutch")

# %%
print(s_qry)
# Out:
# SELECT driverID, forename, surname FROM drivers WHERE nationality = "Dutch"

# %%
# and here's the table for that query
data = pd.read_sql_query(str(s_qry), con=engine)
data.head()
# Out:
#    driverId    forename       surname
# 0        27  Christijan        Albers
# 1        38      Robert      Doornbos
# 2        50         Jos    Verstappen
# 3       136         Jan       Lammers
# 4       179        Huub  Rothengatter

# %%
# add a 2nd where statement
s_qry.where(attr="DriverId", cond=800, eq='<', d=True)
print(s_qry)
# Out:
# SELECT driverID, forename, surname FROM drivers WHERE nationality = "Dutch" AND NOT DriverId < 800

# %%
# now to get the table, call the dataframe
data = pd.read_sql_query(str(s_qry), con=engine)

# %%
data.head()
# Out:
#    driverId forename        surname
# 0       823    Giedo  van der Garde
# 1       830      Max     Verstappen

# %%
# Use a list as a condition

# first, clear all the filters
s_qry.where(clear=True)

# check it out
print(s_qry)
# Out:
# SELECT driverID, forename, surname FROM drivers

# %%
s_qry.where(attr="nationality", cond=["Dutch", "Belgian"])

# %%
print(s_qry)
# note that this will OR the parameters
# Out:
# SELECT driverID, forename, surname FROM drivers WHERE (nationality = "Dutch" OR nationality = "Belgian")

# %%
# now get the dataframe/table back
data = pd.read_sql_query(str(s_qry), con=engine)
data.head()
# Out:
#    driverId    forename     surname
# 0        27  Christijan      Albers
# 1        38      Robert    Doornbos
# 2        50         Jos  Verstappen
# 3        92    Bertrand      Gachot
# 4       113    Philippe       Adams

# %%
# # try a select all
# s_qry2 = sql_select("SELECT * FROM tasks", 'drivers')

# %%
# Video 3
# https://www.youtube.com/watch?v=uu09SgA0xuc

# Group by and Having

# create a new select with a group by
# notice that you can use SQL aliases
s_qryV3 = sql_select( sl=['nationality', 'COUNT(driverId) as cnt'],
                    fr='drivers',
                    gb='nationality')

# %%
print(s_qryV3)
# Out:
# SELECT nationality, COUNT(driverId) as cnt FROM drivers GROUP BY nationality

# %%
dataV3 = pd.read_sql_query(str(s_qryV3), con=engine)

# %%
import seaborn as sns

# %%
# cm = sns.light_palette("red", as_cmap=True)

# %%
dataV3.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row0_col1 {
#             background-color:  #e5e419;
#             color:  #000000;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row1_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row2_col1 {
#             background-color:  #46327e;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row3_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row4_col1 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row5_col1 {
#             background-color:  #481f70;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row6_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row7_col1 {
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row8_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row9_col1 {
#             background-color:  #481b6d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row10_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row11_col1 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row12_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row13_col1 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row14_col1 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row15_col1 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row16_col1 {
#             background-color:  #471365;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row17_col1 {
#             background-color:  #26828e;
#             color:  #000000;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row18_col1 {
#             background-color:  #355e8d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row19_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row20_col1 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row21_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row22_col1 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row23_col1 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row24_col1 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row25_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row26_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row27_col1 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row28_col1 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row29_col1 {
#             background-color:  #471365;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row30_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row31_col1 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row32_col1 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row33_col1 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row34_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row35_col1 {
#             background-color:  #481f70;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row36_col1 {
#             background-color:  #481668;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row37_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row38_col1 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row39_col1 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row40_col1 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }</style><table id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nationality</th>        <th class="col_heading level0 col1" >cnt</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row0_col0" class="data row0 col0" >American</td>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row0_col1" class="data row0 col1" >157</td>
#             </tr>
#             <tr>
#                         <th id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row1_col0" class="data row1 col0" >American-Italian</td>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row2_col0" class="data row2 col0" >Argentine</td>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row2_col1" class="data row2 col1" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row3_col0" class="data row3 col0" >Argentine-Italian</td>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row3_col1" class="data row3 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row4_col0" class="data row4 col0" >Australian</td>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row4_col1" class="data row4 col1" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5e320db4_8fe8_11ea_8c77_7cb27dedc1c7row5_col0" class="data row5 col0" >Austrian</td>

# %%
dataV3.head()
# Out:
#          nationality  cnt
# 0           American  157
# 1   American-Italian    1
# 2          Argentine   24
# 3  Argentine-Italian    1
# 4         Australian   17

# %%
dataV3.style.set_properties(**{'background-color': 'black',
                            'color': 'lawngreen',
                            'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row1_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row1_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row2_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row2_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row3_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row3_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row4_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row4_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row5_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row5_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row6_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row6_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row7_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row7_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row8_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row8_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row9_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row9_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row10_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row10_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row11_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row11_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row12_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row12_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row13_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row13_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row14_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row14_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row15_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row15_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row16_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row16_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row17_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row17_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row18_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row18_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row19_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row19_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row20_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row20_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row21_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row21_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row22_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row22_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row23_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_5e393386_8fe8_11ea_984d_7cb27dedc1c7row23_col1 {
#             background-color:  black;

# %%
# # and per Video # 3, filter with .having method
# works the same as where
s_qryV3.having(attr='COUNT(driverId)', cond=100, eq='>')

# %%
print(s_qryV3)
# Out:
# SELECT nationality, COUNT(driverId) as cnt FROM drivers GROUP BY nationality HAVING COUNT(driverId) > 100

# %%
dataV3 = pd.read_sql_query(str(s_qryV3), con=engine)

# %%
dataV3.head()
# Out:
#   nationality  cnt
# 0    American  157
# 1     British  164
